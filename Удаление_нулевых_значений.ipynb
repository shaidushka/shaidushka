# %% [markdown]
# <a href="https://colab.research.google.com/github/shaidushka/shaidushka/blob/main/%D0%A3%D0%B4%D0%B0%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BD%D1%83%D0%BB%D0%B5%D0%B2%D1%8B%D1%85_%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B8%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/df_nnz (1).csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#        Km    Vmax  id  activity      X     IR  pot2   ph  temp  dstr  ...  \
# 0  0.0065  1.3763   1         1  2.757  1.071 -0.05  4.0  37.0     3  ...
# 1  0.0554  0.2643   2         1  2.757  1.071 -0.05  4.0  37.0     3  ...
# 2  0.0355   8.363   3         1  2.757  1.071 -0.05  4.0  37.0     3  ...
# 3  0.2277  0.4382   4         1  2.757  1.071 -0.05  4.0  37.0     3  ...
# 4  0.0173  1.0272   5         1  2.757  1.071 -0.05  4.0  37.0     3  ...
#
#    TPSA2  TPSA  XLogP  MaxEStateIndex.1  MaxEStateIndex.2  MinPartialCharge.1  \
# 0   40.5  37.3    6.5          5.992739          6.000000           -0.398299
# 1   40.5  37.3    6.5          5.992739          6.000000           -0.398299
# 2   52.0  37.3    6.5          6.000000          5.992739           -0.254557
# 3   52.0  37.3    6.5          6.000000          5.992739           -0.254557
# 4   40.5  37.3    6.5          5.992739          6.000000           -0.398299
#
# ...

# %%
# Список столбцов, в которых нужно проверить наличие цифры 0
columns_to_check = ["Km", "Vmax", "activity", "ph"]

# Удаление строк, содержащих 0 в указанных столбцах
for column in columns_to_check:
    df = df[df[column] != 0]

# Вывод результата
print(df)
# Out:
#           Km      Vmax    id  activity      X     IR  pot2    ph  temp  dstr  \
# 0     0.0065    1.3763     1         1  2.757  1.071 -0.05  4.00  37.0     3
# 1     0.0554    0.2643     2         1  2.757  1.071 -0.05  4.00  37.0     3
# 2     0.0355     8.363     3         1  2.757  1.071 -0.05  4.00  37.0     3
# 3     0.2277    0.4382     4         1  2.757  1.071 -0.05  4.00  37.0     3
# 4     0.0173    1.0272     5         1  2.757  1.071 -0.05  4.00  37.0     3
# ...      ...       ...   ...       ...    ...    ...   ...   ...   ...   ...
# 1125   0.122  1.51E-06  1198         2  2.280  1.350  1.20  7.00  41.4     3
# 1126   0.027  0.000252  1199         2  2.280  1.350  1.20  3.00  33.0     1
# 1127   0.035  0.000177  1200         2  2.280  1.350  1.20  7.00  33.0     1
# 1128   0.163  4.08E-05  1201         2  1.937  0.853  0.78  4.00  42.4     1
# 1129   102.4    0.0022  1203         3  2.200  0.730  0.83  4.24  47.0     3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1130 entries, 0 to 1129
# Data columns (total 48 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Km                  1130 non-null   object
#  1   Vmax                1130 non-null   object
#  2   id                  1130 non-null   int64
#  3   activity            1130 non-null   int64
#  4   X                   1130 non-null   float64
#  5   IR                  1130 non-null   float64
#  6   pot2                1130 non-null   float64
#  7   ph                  1127 non-null   float64
#  8   temp                1129 non-null   float64
#  9   dstr                1130 non-null   int64
#  10  cryst               1130 non-null   float64
#  11  lgCmin              1130 non-null   float64
#  12  lgCmax              1130 non-null   float64
#  13  Cmin                1130 non-null   float64
#  14  Cmax                1130 non-null   float64
# ...
